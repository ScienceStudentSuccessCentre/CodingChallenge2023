# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Tools for the Fun Carnival Mirror Challenge
import matplotlib.pyplot as plt
import cv2 as cv

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/funcarnivalmirrorimages/thirdStep.jpg
# /kaggle/input/funcarnivalmirrorimages/secondStep.jpg
# /kaggle/input/funcarnivalmirrorimages/fourthStep.jpg
# /kaggle/input/funcarnivalmirrorimages/photoA.jpg
# /kaggle/input/funcarnivalmirrorimages/fifthStep.jpg
# /kaggle/input/funcarnivalmirrorimages/firstStep.jpg
# /kaggle/input/funcarnivalmirrorimages/photoB.jpg

# %% [markdown]
# # Fun Carnival Mirror Challenge
#
# **Before we start**, you have to add our dataset. In the right sidebar, you will find the button to add it. Type `FunCarnivalMirrorImages` in the search bar. Click on the plus sign icon on the right of the list entry. Also, don't forget to run the cell above these instructions; they will load all the modules needed for this challenge.
#
# Please look below to find two images: A and B. We have used code to transform the Carleton University logo into a trippy version, like a Funhouse Carnival Mirror! To complete the challenge, we will guide you through each modification needed to turn photo A into photo B. You will have to fill in the gaps based on the expected output we will show you.
#
# We will use the first modification as an example for you to get comfortable with the challenge’s dynamic.

# %%
photoA = cv.imread('/kaggle/input/funcarnivalmirrorimages/photoA.jpg')
photoB = cv.imread('/kaggle/input/funcarnivalmirrorimages/photoB.jpg')

# %%
plt.figure(figsize=(20, 20))

plt.subplot(1, 2, 1)
plt.title("Photo A")
plt.imshow(photoA)
plt.subplot(1, 2, 2)
plt.title("Photo B")
plt.imshow(photoB)

# %% [markdown]
# # Modification 1: Colour Space Convertion
#
# As you may have noticed, OpenCV reads the images in blue colour instead of the characteristic Carleton red. This is because, by default, OpenCV reads the image as Blue, Green, Red (BGR) instead of Red, Blue, Green (RGB). Therefore, you have to change the colour space used to read the image. A colour space describes a specific, measurable, and fixed range of possible colours and luminance values" [[1](https://blog.frame.io/2020/02/03/color-spaces-101/#What_is_color_space)].
#
# The following function transforms one colour space to another, with the colour space being denoted by a cv2-provided constant [[2](https://docs.opencv.org/3.4/d8/d01/group__imgproc__color__conversions.html#gga4e0972be5de079fed4e3a10e24ef5ef0a4f17670b4ee8da649dc368629230c990)].
#
# `cv1.cvtColor(source, color_space)`
#
# - source: image read using cv2
# - color_space: ColorConvertionCode

# %%
photoA = cv.cvtColor(photoA, cv.COLOR_BGR2RGB)
photoB = cv.cvtColor(photoB, cv.COLOR_BGR2RGB)

# %%
# Run this code to see the images
plt.figure(figsize=(20, 20))

plt.subplot(1, 2, 1)
plt.title("Photo A")
plt.imshow(photoA)
plt.subplot(1, 2, 2)
plt.title("Photo B")
plt.imshow(photoB)

# %% [markdown]
# # Modification 2: Cropping [20 points]

# %%
# Put your code here


# photoA = ...

# %%
# Run this cell to show the images
plt.figure(figsize=(20, 20))

plt.subplot(1, 2, 1)
plt.title("Photo A")
plt.imshow(photoA)

plt.subplot(1, 2, 2)
plt.title("Expected Output")
plt.imshow(cv.cvtColor(cv.imread('/kaggle/input/funcarnivalmirrorimages/firstStep.jpg'), cv.COLOR_BGR2RGB))

# %% [markdown]
# # Modification 3: Scaling [20 points]

# %%
# Put your code here


# photoA = ...

# %%
# Run this cell to see the images
plt.figure(figsize=(20, 20))

plt.subplot(1, 2, 1)
plt.title("Photo A")
plt.imshow(photoA)

plt.subplot(1, 2, 2)
plt.title("Expected Output")
plt.imshow(cv.cvtColor(cv.imread('/kaggle/input/funcarnivalmirrorimages/secondStep.jpg'), cv.COLOR_BGR2RGB))

# %% [markdown]
# # Modification 4: Contouring [20 points]

# %%
# Put your code here

# %%
# Run this cell to see the images
plt.figure(figsize=(20, 20))

plt.subplot(1, 2, 1)
plt.title("Photo A")
plt.imshow(photoA)

plt.subplot(1, 2, 2)
plt.title("Expected Output")
plt.imshow(cv.cvtColor(cv.imread('/kaggle/input/funcarnivalmirrorimages/thirdStep.jpg'), cv.COLOR_BGR2RGB))

# %% [markdown]
# # Modification 5: Blurring [20 points]

# %%
# Put your code here


# photoA = ...

# %%
# Run this cell to see the images
plt.figure(figsize=(20, 20))

plt.subplot(1, 2, 1)
plt.title("Photo A")
plt.imshow(photoA)

plt.subplot(1, 2, 2)
plt.title("Expected Output")
plt.imshow(cv.cvtColor(cv.imread('/kaggle/input/funcarnivalmirrorimages/fourthStep.jpg'), cv.COLOR_BGR2RGB))

# %% [markdown]
# # Modification 6: Dilation [20 points]

# %%
# Put your code here


# photoA = ...

# %%
# Run this cell to see the images
plt.figure(figsize=(20, 20))

plt.subplot(1, 2, 1)
plt.title("Photo A")
plt.imshow(photoA)

plt.subplot(1, 2, 2)
plt.title("Expected Output")
plt.imshow(cv.cvtColor(cv.imread('/kaggle/input/funcarnivalmirrorimages/fifthStep.jpg'), cv.COLOR_BGR2RGB))
